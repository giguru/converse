# %% [markdown]
# # Open-retrieval Conversation Question Answering
# Based on the paper _Open-retrieval Conversation Question Answering_ by _Qu et al_.
#
# Since ConverSE is built upon Haystack. This notebook is very similar to the original notebook on Dense Passage Retrieval https://colab.research.google.com/github/deepset-ai/haystack/blob/master/tutorials/Tutorial6_Better_Retrieval_via_DPR.ipynb#scrollTo=kFwiPP60A6N7

# %% [markdown]
# ## Prepare environment

# %%
# Make sure you have a GPU running
# !nvidia-smi

# For locals runs... Notebook opens in example dir, should be main
import os
os.chdir("..")

# !pip install git+https://github.com/deepset-ai/haystack.git # Install the latest master of Haystack
# !pip install git+https://github.com/giguru/converse.git  # Install the latest master of Converse
# Out:
# Wed Oct  7 20:47:39 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.100      Driver Version: 440.100      CUDA Version: 10.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 166...  Off  | 00000000:01:00.0  On |                  N/A |
# |  0%   48C    P8    11W / 125W |    761MiB /  5943MiB |     18%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |    0      2027      G   /usr/lib/xorg/Xorg                            18MiB |
# |    0      2081      G   /usr/bin/gnome-shell                          50MiB |
# |    0      4204      G   /usr/lib/xorg/Xorg                           184MiB |
# |    0      4339      G   /usr/bin/gnome-shell                         157MiB |
# |    0      4889      G   ...AAAAAAAAAAAAAAgAAAAAAAAA --shared-files   248MiB |
# |    0     11283      G   .../share/spotify/debug.log --shared-files    64MiB |
# |    0     23812      G   ...e/Downloads/pycharm-2020.1/jbr/bin/java    32MiB |
# +-----------------------------------------------------------------------------+
# Collecting git+https://github.com/deepset-ai/haystack.git
#   Cloning https://github.com/deepset-ai/haystack.git to /tmp/pip-req-build-fg6qqd1o
# Requirement already satisfied (use --upgrade to upgrade): farm-haystack==0.4.0 from git+https://github.com/deepset-ai/haystack.git in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages
# Requirement already satisfied: farm==0.4.9 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from farm-haystack==0.4.0) (0.4.9)
# Requirement already satisfied: fastapi in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from farm-haystack==0.4.0) (0.61.1)
# Requirement already satisfied: uvicorn in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from farm-haystack==0.4.0) (0.12.1)
# Requirement already satisfied: gunicorn in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from farm-haystack==0.4.0) (20.0.4)
# Requirement already satisfied: pandas in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from farm-haystack==0.4.0) (1.1.3)
# Requirement already satisfied: psycopg2-binary in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from farm-haystack==0.4.0) (2.8.6)
# Requirement already satisfied: sklearn in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from farm-haystack==0.4.0) (0.0)
# Requirement already satisfied: elasticsearch in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from farm-haystack==0.4.0) (7.9.1)
# Requirement already satisfied: elastic-apm in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from farm-haystack==0.4.0) (5.9.0)
# Requirement already satisfied: tox in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from farm-haystack==0.4.0) (3.20.0)
# Requirement already satisfied: coverage in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from farm-haystack==0.4.0) (5.3)
# Requirement already satisfied: langdetect in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from farm-haystack==0.4.0) (1.0.8)
# Requirement already satisfied: python-multipart in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from farm-haystack==0.4.0) (0.0.5)
# Requirement already satisfied: python-docx in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from farm-haystack==0.4.0) (0.8.10)
# Requirement already satisfied: sqlalchemy_utils in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from farm-haystack==0.4.0) (0.36.8)
# Requirement already satisfied: faiss-cpu in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from farm-haystack==0.4.0) (1.6.3)
# Requirement already satisfied: tika in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from farm-haystack==0.4.0) (1.24)
# Requirement already satisfied: uvloop in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from farm-haystack==0.4.0) (0.14.0)
# Requirement already satisfied: httptools in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from farm-haystack==0.4.0) (0.1.1)
# Requirement already satisfied: flask in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from farm==0.4.9->farm-haystack==0.4.0) (1.1.2)
# Requirement already satisfied: Werkzeug==0.16.1 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from farm==0.4.9->farm-haystack==0.4.0) (0.16.1)
# Requirement already satisfied: flask-restplus in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from farm==0.4.9->farm-haystack==0.4.0) (0.13.0)
# Requirement already satisfied: wheel in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from farm==0.4.9->farm-haystack==0.4.0) (0.35.1)
# Requirement already satisfied: seqeval in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from farm==0.4.9->farm-haystack==0.4.0) (0.0.19)
# Requirement already satisfied: mlflow==1.0.0 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from farm==0.4.9->farm-haystack==0.4.0) (1.0.0)
# Requirement already satisfied: dill in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from farm==0.4.9->farm-haystack==0.4.0) (0.3.2)
# Requirement already satisfied: transformers==3.1.0 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from farm==0.4.9->farm-haystack==0.4.0) (3.1.0)
# Requirement already satisfied: dotmap==1.3.0 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from farm==0.4.9->farm-haystack==0.4.0) (1.3.0)
# Requirement already satisfied: boto3 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from farm==0.4.9->farm-haystack==0.4.0) (1.15.13)
# Requirement already satisfied: setuptools in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from farm==0.4.9->farm-haystack==0.4.0) (50.3.0.post20201006)
# Requirement already satisfied: tqdm in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from farm==0.4.9->farm-haystack==0.4.0) (4.50.0)
# Requirement already satisfied: requests in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from farm==0.4.9->farm-haystack==0.4.0) (2.24.0)
# Requirement already satisfied: flask-cors in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from farm==0.4.9->farm-haystack==0.4.0) (3.0.9)
# Requirement already satisfied: psutil in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from farm==0.4.9->farm-haystack==0.4.0) (5.7.2)
# Requirement already satisfied: scipy>=1.3.2 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from farm==0.4.9->farm-haystack==0.4.0) (1.5.2)
# Requirement already satisfied: torch<1.7,>1.5 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from farm==0.4.9->farm-haystack==0.4.0) (1.6.0)
# Requirement already satisfied: pydantic<2.0.0,>=1.0.0 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from fastapi->farm-haystack==0.4.0) (1.6.1)
# Requirement already satisfied: starlette==0.13.6 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from fastapi->farm-haystack==0.4.0) (0.13.6)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from uvicorn->farm-haystack==0.4.0) (3.7.4.3)
# Requirement already satisfied: click==7.* in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from uvicorn->farm-haystack==0.4.0) (7.1.2)
# Requirement already satisfied: h11>=0.8 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from uvicorn->farm-haystack==0.4.0) (0.11.0)
# Requirement already satisfied: pytz>=2017.2 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from pandas->farm-haystack==0.4.0) (2020.1)
# Requirement already satisfied: numpy>=1.15.4 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from pandas->farm-haystack==0.4.0) (1.19.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from pandas->farm-haystack==0.4.0) (2.8.1)
# Requirement already satisfied: scikit-learn in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from sklearn->farm-haystack==0.4.0) (0.23.2)
# Requirement already satisfied: urllib3>=1.21.1 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from elasticsearch->farm-haystack==0.4.0) (1.25.10)
# Requirement already satisfied: certifi in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from elasticsearch->farm-haystack==0.4.0) (2020.6.20)
# Requirement already satisfied: py>=1.4.17 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from tox->farm-haystack==0.4.0) (1.9.0)
# Requirement already satisfied: pluggy>=0.12.0 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from tox->farm-haystack==0.4.0) (0.13.1)
# Requirement already satisfied: importlib-metadata<2,>=0.12; python_version < "3.8" in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from tox->farm-haystack==0.4.0) (1.7.0)
# Requirement already satisfied: toml>=0.9.4 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from tox->farm-haystack==0.4.0) (0.10.1)
# Requirement already satisfied: filelock>=3.0.0 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from tox->farm-haystack==0.4.0) (3.0.12)
# Requirement already satisfied: virtualenv!=20.0.0,!=20.0.1,!=20.0.2,!=20.0.3,!=20.0.4,!=20.0.5,!=20.0.6,!=20.0.7,>=16.0.0 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from tox->farm-haystack==0.4.0) (20.0.33)
# Requirement already satisfied: six>=1.14.0 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from tox->farm-haystack==0.4.0) (1.15.0)
# Requirement already satisfied: packaging>=14 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from tox->farm-haystack==0.4.0) (20.4)
# Requirement already satisfied: lxml>=2.3.2 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from python-docx->farm-haystack==0.4.0) (4.5.2)
# Requirement already satisfied: SQLAlchemy>=1.0 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from sqlalchemy_utils->farm-haystack==0.4.0) (1.3.19)
# Requirement already satisfied: itsdangerous>=0.24 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from flask->farm==0.4.9->farm-haystack==0.4.0) (1.1.0)
# Requirement already satisfied: Jinja2>=2.10.1 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from flask->farm==0.4.9->farm-haystack==0.4.0) (2.11.2)
# Requirement already satisfied: jsonschema in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from flask-restplus->farm==0.4.9->farm-haystack==0.4.0) (3.2.0)
# Requirement already satisfied: aniso8601>=0.82 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from flask-restplus->farm==0.4.9->farm-haystack==0.4.0) (8.0.0)
# Requirement already satisfied: Keras>=2.2.4 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from seqeval->farm==0.4.9->farm-haystack==0.4.0) (2.4.3)
# Requirement already satisfied: databricks-cli>=0.8.0 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from mlflow==1.0.0->farm==0.4.9->farm-haystack==0.4.0) (0.12.0)
# Requirement already satisfied: querystring-parser in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from mlflow==1.0.0->farm==0.4.9->farm-haystack==0.4.0) (1.2.4)
# Requirement already satisfied: alembic in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from mlflow==1.0.0->farm==0.4.9->farm-haystack==0.4.0) (1.4.3)
# Requirement already satisfied: protobuf>=3.6.0 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from mlflow==1.0.0->farm==0.4.9->farm-haystack==0.4.0) (3.13.0)
# Requirement already satisfied: sqlparse in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from mlflow==1.0.0->farm==0.4.9->farm-haystack==0.4.0) (0.4.0)
# Requirement already satisfied: pyyaml in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from mlflow==1.0.0->farm==0.4.9->farm-haystack==0.4.0) (5.3.1)
# Requirement already satisfied: simplejson in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from mlflow==1.0.0->farm==0.4.9->farm-haystack==0.4.0) (3.17.2)
# Requirement already satisfied: docker>=3.6.0 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from mlflow==1.0.0->farm==0.4.9->farm-haystack==0.4.0) (4.3.1)
# Requirement already satisfied: cloudpickle in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from mlflow==1.0.0->farm==0.4.9->farm-haystack==0.4.0) (1.6.0)
# Requirement already satisfied: entrypoints in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from mlflow==1.0.0->farm==0.4.9->farm-haystack==0.4.0) (0.3)
# Requirement already satisfied: gitpython>=2.1.0 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from mlflow==1.0.0->farm==0.4.9->farm-haystack==0.4.0) (3.1.9)
# Requirement already satisfied: tokenizers==0.8.1.rc2 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from transformers==3.1.0->farm==0.4.9->farm-haystack==0.4.0) (0.8.1rc2)
# Requirement already satisfied: regex!=2019.12.17 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from transformers==3.1.0->farm==0.4.9->farm-haystack==0.4.0) (2020.9.27)
# Requirement already satisfied: sacremoses in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from transformers==3.1.0->farm==0.4.9->farm-haystack==0.4.0) (0.0.43)
# Requirement already satisfied: sentencepiece!=0.1.92 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from transformers==3.1.0->farm==0.4.9->farm-haystack==0.4.0) (0.1.91)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from boto3->farm==0.4.9->farm-haystack==0.4.0) (0.10.0)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from boto3->farm==0.4.9->farm-haystack==0.4.0) (0.3.3)
# Requirement already satisfied: botocore<1.19.0,>=1.18.13 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from boto3->farm==0.4.9->farm-haystack==0.4.0) (1.18.13)
# Requirement already satisfied: idna<3,>=2.5 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from requests->farm==0.4.9->farm-haystack==0.4.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from requests->farm==0.4.9->farm-haystack==0.4.0) (3.0.4)
# Requirement already satisfied: future in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from torch<1.7,>1.5->farm==0.4.9->farm-haystack==0.4.0) (0.18.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from scikit-learn->sklearn->farm-haystack==0.4.0) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from scikit-learn->sklearn->farm-haystack==0.4.0) (0.17.0)
# Requirement already satisfied: zipp>=0.5 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from importlib-metadata<2,>=0.12; python_version < "3.8"->tox->farm-haystack==0.4.0) (3.3.0)
# Requirement already satisfied: distlib<1,>=0.3.1 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from virtualenv!=20.0.0,!=20.0.1,!=20.0.2,!=20.0.3,!=20.0.4,!=20.0.5,!=20.0.6,!=20.0.7,>=16.0.0->tox->farm-haystack==0.4.0) (0.3.1)
# Requirement already satisfied: appdirs<2,>=1.4.3 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from virtualenv!=20.0.0,!=20.0.1,!=20.0.2,!=20.0.3,!=20.0.4,!=20.0.5,!=20.0.6,!=20.0.7,>=16.0.0->tox->farm-haystack==0.4.0) (1.4.4)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from packaging>=14->tox->farm-haystack==0.4.0) (2.4.7)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from Jinja2>=2.10.1->flask->farm==0.4.9->farm-haystack==0.4.0) (1.1.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from jsonschema->flask-restplus->farm==0.4.9->farm-haystack==0.4.0) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from jsonschema->flask-restplus->farm==0.4.9->farm-haystack==0.4.0) (20.2.0)
# Requirement already satisfied: h5py in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from Keras>=2.2.4->seqeval->farm==0.4.9->farm-haystack==0.4.0) (2.10.0)
# Requirement already satisfied: tenacity>=6.2.0 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from databricks-cli>=0.8.0->mlflow==1.0.0->farm==0.4.9->farm-haystack==0.4.0) (6.2.0)
# Requirement already satisfied: tabulate>=0.7.7 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from databricks-cli>=0.8.0->mlflow==1.0.0->farm==0.4.9->farm-haystack==0.4.0) (0.8.7)
# Requirement already satisfied: python-editor>=0.3 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from alembic->mlflow==1.0.0->farm==0.4.9->farm-haystack==0.4.0) (1.0.4)
# Requirement already satisfied: Mako in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from alembic->mlflow==1.0.0->farm==0.4.9->farm-haystack==0.4.0) (1.1.3)
# Requirement already satisfied: websocket-client>=0.32.0 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from docker>=3.6.0->mlflow==1.0.0->farm==0.4.9->farm-haystack==0.4.0) (0.57.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from gitpython>=2.1.0->mlflow==1.0.0->farm==0.4.9->farm-haystack==0.4.0) (4.0.5)
# Requirement already satisfied: smmap<4,>=3.0.1 in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages (from gitdb<5,>=4.0.1->gitpython>=2.1.0->mlflow==1.0.0->farm==0.4.9->farm-haystack==0.4.0) (3.0.4)
# Building wheels for collected packages: farm-haystack
# done
#   Created wheel for farm-haystack: filename=farm_haystack-0.4.0-py3-none-any.whl size=83509 sha256=f476c16c4e5f579306da73eb12b9de16b7af49fd8f592b796f54774666d04e0f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-99terkv7/wheels/a7/05/3b/9b33368d9af06a39f8e6af2e97fa2af876e893ade323cfc2c9
# Successfully built farm-haystack
# Collecting git+https://github.com/giguru/converse.git
#   Cloning https://github.com/giguru/converse.git to /tmp/pip-req-build-550huahj
# Requirement already satisfied (use --upgrade to upgrade): converse==0.0.1 from git+https://github.com/giguru/converse.git in /home/melle/miniconda3/envs/converse/lib/python3.7/site-packages
# Building wheels for collected packages: converse
# done
#   Created wheel for converse: filename=converse-0.0.1-py3-none-any.whl size=50409 sha256=167838a2063d0ccaf00d54ec531c64441056429c3502f1c198d7d97d0137363d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3vbf2xwe/wheels/0b/ea/3c/2dee8e6602ddd4d7a073dd4e630015e52f3e637fc5269a6da6
# Successfully built converse

# %%
from haystack import Finder
from haystack.preprocessor.cleaning import clean_wiki_text
from haystack.preprocessor.utils import convert_files_to_dicts, fetch_archive_from_http
from haystack.reader.farm import FARMReader
from haystack.reader.transformers import TransformersReader
from haystack.utils import print_answers

from converse.src.reader.farm import FARMReader
from converse.src.reader.transformers import TransformersReader
from converse.src.retriever.dense_passage_retriever import DensePassageRetriever
from converse.src.converse import Converse

# %% [markdown]
# ## Indexer and data

# %%
# Add document collection to a DocumentStore. The original text will be indexed. Conversion into embeddings can be 
# is done below.
from haystack.document_store.faiss import FAISSDocumentStore
document_store = FAISSDocumentStore()
# Out:
# 10/07/2020 20:47:50 - INFO - faiss -   Loading faiss.

# %%
from converse.src.retriever.dense_passage_retriever import DensePassageRetriever
retriever = DensePassageRetriever(
    document_store=document_store,
    query_embedding_model="facebook/dpr-question_encoder-single-nq-base",  # TODO replace with ORConvQA model
    passage_embedding_model="facebook/dpr-ctx_encoder-single-nq-base",  # TODO replace with ORConvQA model
    use_gpu=True,
    embed_title=True,
    max_seq_len=256,
    batch_size=16,
    remove_sep_tok_from_untitled_passages=True
)
# Out:
# Some weights of DPRQuestionEncoder were not initialized from the model checkpoint at facebook/dpr-question_encoder-single-nq-base and are newly initialized: ['question_encoder.bert_model.embeddings.position_ids']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of DPRContextEncoder were not initialized from the model checkpoint at facebook/dpr-ctx_encoder-single-nq-base and are newly initialized: ['ctx_encoder.bert_model.embeddings.position_ids']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# # Embed passages
# Since retrieval will be done on the embeddings, the embedding representation of the documents need to be computed
# This only needs to be done once.

# %%
# document_store.update_embeddings(retriever)

# %%
# Load a local model or any of the QA models on Hugging Face's model hub (https://huggingface.co/models)
reader = FARMReader(model_name_or_path="deepset/roberta-base-squad2", use_gpu=True)
# Out:
# 10/07/2020 20:48:23 - INFO - farm.utils -   device: cuda n_gpu: 1, distributed training: False, automatic mixed precision training: None
# 10/07/2020 20:48:23 - INFO - farm.infer -   Could not find `deepset/roberta-base-squad2` locally. Try to download from model hub ...
# 10/07/2020 20:48:36 - WARNING - farm.modeling.language_model -   Could not automatically detect from language model name what language it is.
# 	 We guess it's an *ENGLISH* model ...
# 	 If not: Init the language model by supplying the 'language' param.
# 10/07/2020 20:48:53 - WARNING - farm.modeling.prediction_head -   Some unused parameters are passed to the QuestionAnsweringHead. Might not be a problem. Params: {"loss_ignore_index": -1}
# 10/07/2020 20:48:58 - INFO - farm.utils -   device: cuda n_gpu: 1, distributed training: False, automatic mixed precision training: None
# 10/07/2020 20:48:58 - INFO - farm.infer -   Got ya 7 parallel workers to do inference ...
# 10/07/2020 20:48:58 - INFO - farm.infer -    0    0    0    0    0    0    0
# 10/07/2020 20:48:58 - INFO - farm.infer -   /w\  /w\  /w\  /w\  /w\  /w\  /w\
# 10/07/2020 20:48:58 - INFO - farm.infer -   /'\  / \  /'\  /'\  / \  / \  /'\
# 10/07/2020 20:48:58 - INFO - farm.infer -
# Process ForkPoolWorker-7:
# Process ForkPoolWorker-1:
# Process ForkPoolWorker-5:
# Process ForkPoolWorker-2:
# Process ForkPoolWorker-4:
# Process ForkPoolWorker-6:
# Traceback (most recent call last):
# Process ForkPoolWorker-3:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/melle/miniconda3/envs/converse/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/melle/miniconda3/envs/converse/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/melle/miniconda3/envs/converse/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/melle/miniconda3/envs/converse/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/melle/miniconda3/envs/converse/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/melle/miniconda3/envs/converse/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/melle/miniconda3/envs/converse/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/melle/miniconda3/envs/converse/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/melle/miniconda3/envs/converse/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/melle/miniconda3/envs/converse/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/melle/miniconda3/envs/converse/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/melle/miniconda3/envs/converse/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/melle/miniconda3/envs/converse/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/melle/miniconda3/envs/converse/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/melle/miniconda3/envs/converse/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/home/melle/miniconda3/envs/converse/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/melle/miniconda3/envs/converse/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/melle/miniconda3/envs/converse/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/melle/miniconda3/envs/converse/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/melle/miniconda3/envs/converse/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/melle/miniconda3/envs/converse/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/melle/miniconda3/envs/converse/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/melle/miniconda3/envs/converse/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/melle/miniconda3/envs/converse/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/melle/miniconda3/envs/converse/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/melle/miniconda3/envs/converse/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/melle/miniconda3/envs/converse/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/melle/miniconda3/envs/converse/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/melle/miniconda3/envs/converse/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/home/melle/miniconda3/envs/converse/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/melle/miniconda3/envs/converse/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/melle/miniconda3/envs/converse/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/melle/miniconda3/envs/converse/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/melle/miniconda3/envs/converse/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/melle/miniconda3/envs/converse/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/melle/miniconda3/envs/converse/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/melle/miniconda3/envs/converse/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt

# %%
finder = Converse(reader, [retriever])

# %% [markdown]
# ## Evaluate pipeline

# %%
# Evaluate combination of Reader and Retriever through Finder
finder_eval_results = finder.eval(top_k_retriever=1, top_k_reader=10)
finder.print_eval_results(finder_eval_results)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-3941a8927519> in <module>
#       1 # Evaluate combination of Reader and Retriever through Finder
# ----> 2 finder_eval_results = finder.eval(top_k_retriever=1, top_k_reader=10)
#       3 finder.print_eval_results(finder_eval_results)
#       4
#
# TypeError: eval() missing 2 required positional arguments: 'label_index' and 'doc_index'
